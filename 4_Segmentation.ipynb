# %% [markdown]
# # **1. Segmentation**
# Segmentation은 컴퓨터 비전에서 이미지나 영상을 픽셀 단위로 분할하여 각 영역이 무엇을 나타내는지 구분하는 기술입니다. 이는 크게 Semantic Segmentation과 Instance Segmentation으로 나뉘는데, Semantic Segmentation은 같은 종류의 객체를 동일한 클래스로 분류하는 반면, Instance Segmentation은 같은 클래스 내에서도 개별 객체를 구분합니다. 이를 통해 의료 영상 분석, 자율주행, 위성 이미지 처리 등 다양한 분야에서 정밀한 객체 인식을 수행할 수 있습니다. Segmentation 모델로는 U-Net, DeepLab, Mask R-CNN 등이 널리 사용됩니다.
#
# ![세그멘테이션](./images/세그멘테이션.png)

# %% [markdown]
# # **2. 스타벅스 데이터셋**

# %% [markdown]
# ### COCO JSON
# - images: 이미지 ID, 파일명, width, height
# - annotations: 객체의 category, polygon, bbox 등
# - categories: 클래스 ID와 이름

# %%
import json
import random
import shutil
from collections import Counter
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
import numpy as np
import torch
import ultralytics
import yaml

from ultralytics import YOLO

# %%
PROJECT_ROOT = Path.cwd()
DATA_ROOT = PROJECT_ROOT / "data"
SOURCE_DIR = DATA_ROOT / "starbucks"
YOLO_ROOT = DATA_ROOT / "Starbucks_YOLO"
COCO_JSON = SOURCE_DIR / "instances_default.json"

print("PROJECT_ROOT: ", PROJECT_ROOT)
print("SOURCE_DIR: ", SOURCE_DIR)
print("YOLO_ROOT: ", YOLO_ROOT)
print("COCO_JSON: ", COCO_JSON)
# Out:
# PROJECT_ROOT:  c:\HyeonKyu\11_CV
# SOURCE_DIR:  c:\HyeonKyu\11_CV\data\starbucks
# YOLO_ROOT:  c:\HyeonKyu\11_CV\data\Starbucks_YOLO
# COCO_JSON:  c:\HyeonKyu\11_CV\data\starbucks\instances_default.json

# %%
with COCO_JSON.open("r", encoding="utf-8") as f:
    coco_data = json.load(f)
coco_data
# Out:
# {'licenses': [{'name': '', 'id': 0, 'url': ''}],
#  'info': {'contributor': '',
#   'date_created': '',
#   'description': '',
#   'url': '',
#   'version': '',
#   'year': ''},
#  'categories': [{'id': 1, 'name': 'logo', 'supercategory': ''},
#   {'id': 2, 'name': 'text', 'supercategory': ''}],
#  'images': [{'id': 1,
#    'width': 1024,
#    'height': 682,
#    'file_name': '000001.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 2,
#    'width': 885,
#    'height': 960,
#    'file_name': '000002.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 3,
#    'width': 1600,
#    'height': 1155,
#    'file_name': '000003.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 4,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000004.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 5,
#    'width': 900,
#    'height': 1200,
#    'file_name': '000005.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 6,
#    'width': 1000,
#    'height': 1333,
#    'file_name': '000006.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 7,
#    'width': 1300,
#    'height': 1390,
#    'file_name': '000007.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 8,
#    'width': 336,
#    'height': 280,
#    'file_name': '000008.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 9,
#    'width': 1200,
#    'height': 879,
#    'file_name': '000009.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 10,
#    'width': 922,
#    'height': 1500,
#    'file_name': '000010.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 11,
#    'width': 541,
#    'height': 777,
#    'file_name': '000011.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 12,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000012.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 13,
#    'width': 1300,
#    'height': 921,
#    'file_name': '000013.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 14,
#    'width': 1300,
#    'height': 955,
#    'file_name': '000014.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 15,
#    'width': 1000,
#    'height': 736,
#    'file_name': '000015.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 16,
#    'width': 1600,
#    'height': 896,
#    'file_name': '000016.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 17,
#    'width': 960,
#    'height': 750,
#    'file_name': '000017.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 18,
#    'width': 1920,
#    'height': 1920,
#    'file_name': '000018.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 19,
#    'width': 866,
#    'height': 1390,
#    'file_name': '000019.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 20,
#    'width': 3840,
#    'height': 2160,
#    'file_name': '000020.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 21,
#    'width': 1480,
#    'height': 987,
#    'file_name': '000021.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 22,
#    'width': 750,
#    'height': 1000,
#    'file_name': '000022.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 23,
#    'width': 640,
#    'height': 452,
#    'file_name': '000023.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 24,
#    'width': 300,
#    'height': 395,
#    'file_name': '000024.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 25,
#    'width': 5000,
#    'height': 3500,
#    'file_name': '000025.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 26,
#    'width': 1920,
#    'height': 800,
#    'file_name': '000026.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 27,
#    'width': 1920,
#    'height': 1080,
#    'file_name': '000027.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 28,
#    'width': 3000,
#    'height': 4347,
#    'file_name': '000028.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 29,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000029.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 30,
#    'width': 1024,
#    'height': 684,
#    'file_name': '000030.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 31,
#    'width': 450,
#    'height': 320,
#    'file_name': '000031.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 32,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000032.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 33,
#    'width': 390,
#    'height': 280,
#    'file_name': '000033.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 34,
#    'width': 390,
#    'height': 280,
#    'file_name': '000034.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 35,
#    'width': 2048,
#    'height': 1536,
#    'file_name': '000035.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 36,
#    'width': 626,
#    'height': 415,
#    'file_name': '000036.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 37,
#    'width': 1400,
#    'height': 1400,
#    'file_name': '000037.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 38,
#    'width': 1024,
#    'height': 1024,
#    'file_name': '000038.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 39,
#    'width': 1600,
#    'height': 1200,
#    'file_name': '000039.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 40,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000040.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 41,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000041.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 42,
#    'width': 1300,
#    'height': 957,
#    'file_name': '000042.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 43,
#    'width': 1920,
#    'height': 1280,
#    'file_name': '000043.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 44,
#    'width': 1269,
#    'height': 900,
#    'file_name': '000044.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 45,
#    'width': 959,
#    'height': 639,
#    'file_name': '000045.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 46,
#    'width': 1300,
#    'height': 820,
#    'file_name': '000046.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 47,
#    'width': 780,
#    'height': 438,
#    'file_name': '000047.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 48,
#    'width': 650,
#    'height': 806,
#    'file_name': '000048.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 49,
#    'width': 574,
#    'height': 414,
#    'file_name': '000049.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 50,
#    'width': 900,
#    'height': 1200,
#    'file_name': '000050.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 51,
#    'width': 1300,
#    'height': 1065,
#    'file_name': '000051.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 52,
#    'width': 863,
#    'height': 1390,
#    'file_name': '000052.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 53,
#    'width': 2650,
#    'height': 1960,
#    'file_name': '000053.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 54,
#    'width': 3000,
#    'height': 2000,
#    'file_name': '000054.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 55,
#    'width': 736,
#    'height': 981,
#    'file_name': '000055.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 56,
#    'width': 1200,
#    'height': 675,
#    'file_name': '000056.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 57,
#    'width': 2800,
#    'height': 2121,
#    'file_name': '000057.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 58,
#    'width': 1200,
#    'height': 801,
#    'file_name': '000058.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 59,
#    'width': 600,
#    'height': 600,
#    'file_name': '000059.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 60,
#    'width': 2206,
#    'height': 2350,
#    'file_name': '000060.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 61,
#    'width': 980,
#    'height': 656,
#    'file_name': '000061.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 62,
#    'width': 1000,
#    'height': 667,
#    'file_name': '000062.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 63,
#    'width': 2000,
#    'height': 2000,
#    'file_name': '000063.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 64,
#    'width': 612,
#    'height': 408,
#    'file_name': '000064.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 65,
#    'width': 1300,
#    'height': 957,
#    'file_name': '000065.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 66,
#    'width': 992,
#    'height': 661,
#    'file_name': '000066.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 67,
#    'width': 900,
#    'height': 578,
#    'file_name': '000067.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 68,
#    'width': 1600,
#    'height': 1200,
#    'file_name': '000068.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 69,
#    'width': 683,
#    'height': 1024,
#    'file_name': '000069.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 70,
#    'width': 1200,
#    'height': 1055,
#    'file_name': '000070.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 71,
#    'width': 700,
#    'height': 700,
#    'file_name': '000071.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 72,
#    'width': 3024,
#    'height': 4032,
#    'file_name': '000072.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 73,
#    'width': 1200,
#    'height': 601,
#    'file_name': '000073.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 74,
#    'width': 900,
#    'height': 506,
#    'file_name': '000074.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 75,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000075.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 76,
#    'width': 1109,
#    'height': 632,
#    'file_name': '000076.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 77,
#    'width': 1500,
#    'height': 1102,
#    'file_name': '000077.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 78,
#    'width': 866,
#    'height': 1390,
#    'file_name': '000078.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 79,
#    'width': 580,
#    'height': 580,
#    'file_name': '000079.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 80,
#    'width': 1300,
#    'height': 957,
#    'file_name': '000080.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 81,
#    'width': 3264,
#    'height': 2448,
#    'file_name': '000081.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 82,
#    'width': 626,
#    'height': 351,
#    'file_name': '000082.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 83,
#    'width': 1280,
#    'height': 1269,
#    'file_name': '000083.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 84,
#    'width': 400,
#    'height': 255,
#    'file_name': '000084.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 85,
#    'width': 1024,
#    'height': 1024,
#    'file_name': '000085.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 86,
#    'width': 612,
#    'height': 446,
#    'file_name': '000086.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 87,
#    'width': 1588,
#    'height': 1588,
#    'file_name': '000087.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 88,
#    'width': 1024,
#    'height': 1024,
#    'file_name': '000088.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 89,
#    'width': 1920,
#    'height': 1080,
#    'file_name': '000089.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 90,
#    'width': 1200,
#    'height': 630,
#    'file_name': '000090.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 91,
#    'width': 500,
#    'height': 500,
#    'file_name': '000091.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 92,
#    'width': 600,
#    'height': 600,
#    'file_name': '000092.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 93,
#    'width': 612,
#    'height': 408,
#    'file_name': '000093.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 94,
#    'width': 2000,
#    'height': 2000,
#    'file_name': '000094.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 95,
#    'width': 1300,
#    'height': 1142,
#    'file_name': '000095.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 96,
#    'width': 1000,
#    'height': 600,
#    'file_name': '000096.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 97,
#    'width': 934,
#    'height': 1200,
#    'file_name': '000097.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 98,
#    'width': 1300,
#    'height': 998,
#    'file_name': '000098.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 99,
#    'width': 1125,
#    'height': 750,
#    'file_name': '000099.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 100,
#    'width': 1440,
#    'height': 810,
#    'file_name': '000100.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 101,
#    'width': 3000,
#    'height': 1689,
#    'file_name': '000101.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 102,
#    'width': 866,
#    'height': 1390,
#    'file_name': '000102.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 103,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000103.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 104,
#    'width': 736,
#    'height': 981,
#    'file_name': '000104.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 105,
#    'width': 2240,
#    'height': 1400,
#    'file_name': '000105.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 106,
#    'width': 1300,
#    'height': 957,
#    'file_name': '000106.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 107,
#    'width': 1000,
#    'height': 1333,
#    'file_name': '000107.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 108,
#    'width': 600,
#    'height': 404,
#    'file_name': '000108.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 109,
#    'width': 1200,
#    'height': 630,
#    'file_name': '000109.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 110,
#    'width': 734,
#    'height': 396,
#    'file_name': '000110.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 111,
#    'width': 480,
#    'height': 360,
#    'file_name': '000111.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 112,
#    'width': 1600,
#    'height': 1158,
#    'file_name': '000112.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 113,
#    'width': 675,
#    'height': 1200,
#    'file_name': '000113.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 114,
#    'width': 1300,
#    'height': 960,
#    'file_name': '000114.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 115,
#    'width': 612,
#    'height': 323,
#    'file_name': '000115.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 116,
#    'width': 1300,
#    'height': 1097,
#    'file_name': '000116.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 117,
#    'width': 1300,
#    'height': 1012,
#    'file_name': '000117.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 118,
#    'width': 347,
#    'height': 280,
#    'file_name': '000118.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 119,
#    'width': 404,
#    'height': 316,
#    'file_name': '000119.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 120,
#    'width': 2000,
#    'height': 1333,
#    'file_name': '000120.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 121,
#    'width': 3840,
#    'height': 2880,
#    'file_name': '000121.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 122,
#    'width': 736,
#    'height': 919,
#    'file_name': '000122.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 123,
#    'width': 600,
#    'height': 600,
#    'file_name': '000123.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 124,
#    'width': 1300,
#    'height': 954,
#    'file_name': '000124.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 125,
#    'width': 900,
#    'height': 471,
#    'file_name': '000125.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 126,
#    'width': 1000,
#    'height': 1000,
#    'file_name': '000126.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 127,
#    'width': 1300,
#    'height': 957,
#    'file_name': '000127.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 128,
#    'width': 866,
#    'height': 1390,
#    'file_name': '000128.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 129,
#    'width': 1000,
#    'height': 753,
#    'file_name': '000129.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 130,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000130.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 131,
#    'width': 1300,
#    'height': 953,
#    'file_name': '000131.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 132,
#    'width': 736,
#    'height': 1308,
#    'file_name': '000132.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 133,
#    'width': 580,
#    'height': 1740,
#    'file_name': '000133.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 134,
#    'width': 1300,
#    'height': 1065,
#    'file_name': '000134.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 135,
#    'width': 612,
#    'height': 408,
#    'file_name': '000135.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 136,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000136.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 137,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000137.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 138,
#    'width': 866,
#    'height': 1390,
#    'file_name': '000138.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 139,
#    'width': 480,
#    'height': 270,
#    'file_name': '000139.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 140,
#    'width': 736,
#    'height': 1307,
#    'file_name': '000140.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 141,
#    'width': 808,
#    'height': 632,
#    'file_name': '000141.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 142,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000142.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 143,
#    'width': 756,
#    'height': 1008,
#    'file_name': '000143.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 144,
#    'width': 1024,
#    'height': 684,
#    'file_name': '000144.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 145,
#    'width': 1024,
#    'height': 1024,
#    'file_name': '000145.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 146,
#    'width': 2941,
#    'height': 1960,
#    'file_name': '000146.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 147,
#    'width': 675,
#    'height': 1200,
#    'file_name': '000147.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 148,
#    'width': 1024,
#    'height': 906,
#    'file_name': '000148.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 149,
#    'width': 1960,
#    'height': 1100,
#    'file_name': '000149.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 150,
#    'width': 930,
#    'height': 668,
#    'file_name': '000150.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 151,
#    'width': 600,
#    'height': 338,
#    'file_name': '000177.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 152,
#    'width': 1300,
#    'height': 955,
#    'file_name': '000178.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 153,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000179.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 154,
#    'width': 768,
#    'height': 661,
#    'file_name': '000180.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 155,
#    'width': 350,
#    'height': 525,
#    'file_name': '000181.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 156,
#    'width': 1300,
#    'height': 957,
#    'file_name': '000182.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 157,
#    'width': 563,
#    'height': 750,
#    'file_name': '000183.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 158,
#    'width': 626,
#    'height': 626,
#    'file_name': '000184.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 159,
#    'width': 820,
#    'height': 1278,
#    'file_name': '000185.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 160,
#    'width': 863,
#    'height': 1390,
#    'file_name': '000186.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 161,
#    'width': 800,
#    'height': 800,
#    'file_name': '000187.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 162,
#    'width': 1300,
#    'height': 957,
#    'file_name': '000188.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 163,
#    'width': 1588,
#    'height': 1588,
#    'file_name': '000189.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 164,
#    'width': 1920,
#    'height': 1080,
#    'file_name': '000190.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 165,
#    'width': 1300,
#    'height': 957,
#    'file_name': '000191.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 166,
#    'width': 612,
#    'height': 408,
#    'file_name': '000192.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 167,
#    'width': 810,
#    'height': 1080,
#    'file_name': '000195.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 168,
#    'width': 1200,
#    'height': 800,
#    'file_name': '000196.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 169,
#    'width': 768,
#    'height': 1065,
#    'file_name': '000197.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 170,
#    'width': 3000,
#    'height': 2000,
#    'file_name': '000198.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 171,
#    'width': 1300,
#    'height': 957,
#    'file_name': '000199.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 172,
#    'width': 682,
#    'height': 1024,
#    'file_name': '000200.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 173,
#    'width': 760,
#    'height': 428,
#    'file_name': '000201.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 174,
#    'width': 1300,
#    'height': 957,
#    'file_name': '000202.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 175,
#    'width': 1376,
#    'height': 768,
#    'file_name': '000203.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 176,
#    'width': 1200,
#    'height': 713,
#    'file_name': '000204.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 177,
#    'width': 1920,
#    'height': 1080,
#    'file_name': '000205.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 178,
#    'width': 1300,
#    'height': 955,
#    'file_name': '000206.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 179,
#    'width': 1400,
#    'height': 1000,
#    'file_name': '000207.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 180,
#    'width': 720,
#    'height': 720,
#    'file_name': '000208.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 181,
#    'width': 866,
#    'height': 1390,
#    'file_name': '000209.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 182,
#    'width': 1300,
#    'height': 957,
#    'file_name': '000210.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 183,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000211.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 184,
#    'width': 2592,
#    'height': 1936,
#    'file_name': '000212.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 185,
#    'width': 683,
#    'height': 1024,
#    'file_name': '000213.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 186,
#    'width': 1920,
#    'height': 1080,
#    'file_name': '000214.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 187,
#    'width': 1024,
#    'height': 1024,
#    'file_name': '000215.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 188,
#    'width': 2940,
#    'height': 1960,
#    'file_name': '000216.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 189,
#    'width': 800,
#    'height': 800,
#    'file_name': '000217.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 190,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000218.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 191,
#    'width': 2112,
#    'height': 1668,
#    'file_name': '000219.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 192,
#    'width': 866,
#    'height': 1390,
#    'file_name': '000220.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 193,
#    'width': 866,
#    'height': 1390,
#    'file_name': '000222.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 194,
#    'width': 3000,
#    'height': 2257,
#    'file_name': '000223.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 195,
#    'width': 1080,
#    'height': 1080,
#    'file_name': '000224.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 196,
#    'width': 1125,
#    'height': 750,
#    'file_name': '000225.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 197,
#    'width': 932,
#    'height': 700,
#    'file_name': '000226.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 198,
#    'width': 1300,
#    'height': 821,
#    'file_name': '000227.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 199,
#    'width': 3840,
#    'height': 2160,
#    'file_name': '000228.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 200,
#    'width': 3000,
#    'height': 2001,
#    'file_name': '000229.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 201,
#    'width': 1271,
#    'height': 854,
#    'file_name': '000230.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 202,
#    'width': 800,
#    'height': 534,
#    'file_name': '000231.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 203,
#    'width': 1400,
#    'height': 989,
#    'file_name': '000232.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 204,
#    'width': 1440,
#    'height': 1250,
#    'file_name': '000233.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 205,
#    'width': 866,
#    'height': 1390,
#    'file_name': '000234.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 206,
#    'width': 3000,
#    'height': 4500,
#    'file_name': '000235.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 207,
#    'width': 1300,
#    'height': 984,
#    'file_name': '000236.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 208,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000237.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 209,
#    'width': 5904,
#    'height': 3321,
#    'file_name': '000238.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 210,
#    'width': 404,
#    'height': 316,
#    'file_name': '000239.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 211,
#    'width': 3000,
#    'height': 2000,
#    'file_name': '000240.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 212,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000241.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 213,
#    'width': 800,
#    'height': 600,
#    'file_name': '000242.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 214,
#    'width': 1920,
#    'height': 1080,
#    'file_name': '000243.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 215,
#    'width': 960,
#    'height': 960,
#    'file_name': '000244.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 216,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000245.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 217,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000246.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 218,
#    'width': 600,
#    'height': 400,
#    'file_name': '000247.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 219,
#    'width': 1500,
#    'height': 1101,
#    'file_name': '000248.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 220,
#    'width': 500,
#    'height': 500,
#    'file_name': '000249.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 221,
#    'width': 5888,
#    'height': 3925,
#    'file_name': '000250.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 222,
#    'width': 1300,
#    'height': 953,
#    'file_name': '000251.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 223,
#    'width': 600,
#    'height': 900,
#    'file_name': '000252.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 224,
#    'width': 1200,
#    'height': 630,
#    'file_name': '000253.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 225,
#    'width': 1400,
#    'height': 788,
#    'file_name': '000254.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 226,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000255.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 227,
#    'width': 1300,
#    'height': 1019,
#    'file_name': '000256.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 228,
#    'width': 1300,
#    'height': 1065,
#    'file_name': '000257.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 229,
#    'width': 4000,
#    'height': 2667,
#    'file_name': '000258.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 230,
#    'width': 920,
#    'height': 720,
#    'file_name': '000259.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 231,
#    'width': 1588,
#    'height': 2117,
#    'file_name': '000260.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 232,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000261.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 233,
#    'width': 1920,
#    'height': 1080,
#    'file_name': '000262.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 234,
#    'width': 1024,
#    'height': 683,
#    'file_name': '000263.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 235,
#    'width': 612,
#    'height': 612,
#    'file_name': '000264.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 236,
#    'width': 1300,
#    'height': 1063,
#    'file_name': '000265.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 237,
#    'width': 1024,
#    'height': 1024,
#    'file_name': '000266.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 238,
#    'width': 404,
#    'height': 316,
#    'file_name': '000268.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 239,
#    'width': 1125,
#    'height': 1500,
#    'file_name': '000269.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 240,
#    'width': 1500,
#    'height': 1101,
#    'file_name': '000270.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 241,
#    'width': 800,
#    'height': 600,
#    'file_name': '000271.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 242,
#    'width': 1224,
#    'height': 1632,
#    'file_name': '000272.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 243,
#    'width': 1113,
#    'height': 1390,
#    'file_name': '000273.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 244,
#    'width': 1024,
#    'height': 1024,
#    'file_name': '000274.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 245,
#    'width': 500,
#    'height': 750,
#    'file_name': '000275.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 246,
#    'width': 1300,
#    'height': 957,
#    'file_name': '000277.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 247,
#    'width': 1136,
#    'height': 1136,
#    'file_name': '000278.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 248,
#    'width': 3000,
#    'height': 1996,
#    'file_name': '000280.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 249,
#    'width': 1500,
#    'height': 1101,
#    'file_name': '000281.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 250,
#    'width': 700,
#    'height': 700,
#    'file_name': '000282.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 251,
#    'width': 2811,
#    'height': 1312,
#    'file_name': '000284.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 252,
#    'width': 600,
#    'height': 350,
#    'file_name': '000285.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 253,
#    'width': 1300,
#    'height': 955,
#    'file_name': '000286.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 254,
#    'width': 1300,
#    'height': 953,
#    'file_name': '000288.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 255,
#    'width': 4032,
#    'height': 3024,
#    'file_name': '000289.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 256,
#    'width': 1024,
#    'height': 768,
#    'file_name': '000290.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 257,
#    'width': 612,
#    'height': 409,
#    'file_name': '000291.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 258,
#    'width': 450,
#    'height': 320,
#    'file_name': '000292.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 259,
#    'width': 1500,
#    'height': 1500,
#    'file_name': '000293.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 260,
#    'width': 1280,
#    'height': 720,
#    'file_name': '000295.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 261,
#    'width': 2250,
#    'height': 1500,
#    'file_name': '000296.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 262,
#    'width': 4096,
#    'height': 2160,
#    'file_name': '000297.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 263,
#    'width': 368,
#    'height': 280,
#    'file_name': '000298.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 264,
#    'width': 800,
#    'height': 1619,
#    'file_name': '000299.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 265,
#    'width': 900,
#    'height': 1200,
#    'file_name': '000300.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 266,
#    'width': 1440,
#    'height': 1250,
#    'file_name': '000302.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 267,
#    'width': 736,
#    'height': 552,
#    'file_name': '000303.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 268,
#    'width': 1000,
#    'height': 1333,
#    'file_name': '000304.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 269,
#    'width': 1920,
#    'height': 1080,
#    'file_name': '000305.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 270,
#    'width': 975,
#    'height': 1390,
#    'file_name': '000306.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 271,
#    'width': 1300,
#    'height': 957,
#    'file_name': '000308.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 272,
#    'width': 1470,
#    'height': 980,
#    'file_name': '000309.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 273,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000310.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 274,
#    'width': 1200,
#    'height': 1800,
#    'file_name': '000311.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 275,
#    'width': 1200,
#    'height': 1200,
#    'file_name': '000312.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 276,
#    'width': 1200,
#    'height': 1079,
#    'file_name': '000313.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 277,
#    'width': 1300,
#    'height': 938,
#    'file_name': '000314.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 278,
#    'width': 1500,
#    'height': 1101,
#    'file_name': '000315.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 279,
#    'width': 3176,
#    'height': 3176,
#    'file_name': '000316.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 280,
#    'width': 1300,
#    'height': 1123,
#    'file_name': '000317.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 281,
#    'width': 1300,
#    'height': 955,
#    'file_name': '000318.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 282,
#    'width': 390,
#    'height': 280,
#    'file_name': '000319.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 283,
#    'width': 1300,
#    'height': 1068,
#    'file_name': '000320.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 284,
#    'width': 612,
#    'height': 453,
#    'file_name': '000321.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 285,
#    'width': 1200,
#    'height': 675,
#    'file_name': '000322.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 286,
#    'width': 1400,
#    'height': 1078,
#    'file_name': '000323.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 287,
#    'width': 1600,
#    'height': 1068,
#    'file_name': '000324.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 288,
#    'width': 1200,
#    'height': 879,
#    'file_name': '000325.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 289,
#    'width': 3024,
#    'height': 4032,
#    'file_name': '000326.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 290,
#    'width': 768,
#    'height': 432,
#    'file_name': '000327.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 291,
#    'width': 1300,
#    'height': 956,
#    'file_name': '000328.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 292,
#    'width': 1132,
#    'height': 750,
#    'file_name': '000329.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 293,
#    'width': 800,
#    'height': 422,
#    'file_name': '000330.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 294,
#    'width': 800,
#    'height': 800,
#    'file_name': '000331.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 295,
#    'width': 1300,
#    'height': 957,
#    'file_name': '000332.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 296,
#    'width': 1080,
#    'height': 1080,
#    'file_name': '000333.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 297,
#    'width': 736,
#    'height': 920,
#    'file_name': '000334.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
# ...
#      173.11,
#      91.54,
#      165.85,
#      91.13,
#      150.09]],
#    'area': 1122.0,
#    'bbox': [16.67, 150.09, 74.87, 23.02],
#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   {'id': 980,
#    'image_id': 483,
#    'category_id': 2,
#    'segmentation': [[273.07,
#      144.35,
#      273.71,
#      161.38,
#      358.2,
#      165.88,
#      357.88,
#      150.13]],
#    'area': 1377.0,
#    'bbox': [273.07, 144.35, 85.13, 21.53],
#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   {'id': 981,
#    'image_id': 483,
#    'category_id': 1,
#    'segmentation': [[172.52,
#      136.0,
#      168.03,
#      137.93,
#      165.14,
#      142.1,
#      164.49,
#      146.92,
#      165.78,
#      151.74,
#      169.31,
#      155.6,
#      173.49,
#      158.17,
#      178.31,
#      157.2,
#      181.52,
#      153.03,
#      183.13,
#      147.89,
#      182.48,
#      142.75,
#      179.27,
#      138.89]],
#    'area': 305.0,
#    'bbox': [164.49, 136.0, 18.64, 22.17],
#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   {'id': 982,
#    'image_id': 483,
#    'category_id': 1,
#    'segmentation': [[203.68,
#      135.68,
#      198.54,
#      137.61,
#      196.62,
#      142.42,
#      196.62,
#      147.56,
#      197.26,
#      152.38,
#      200.79,
#      155.92,
#      205.61,
#      156.88,
#      209.15,
#      153.03,
#      209.47,
#      148.21,
#      210.11,
#      143.39,
#      208.82,
#      138.57]],
#    'area': 226.0,
#    'bbox': [196.62, 135.68, 13.49, 21.2],
#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   {'id': 983,
#    'image_id': 484,
#    'category_id': 1,
#    'segmentation': [[526.72,
#      481.82,
#      507.75,
#      483.08,
#      488.77,
#      485.61,
#      471.07,
#      493.2,
#      452.09,
#      500.79,
#      433.12,
#      507.11,
#      416.68,
#      518.5,
#      404.03,
#      533.68,
#      393.91,
#      552.65,
#      386.32,
#      571.62,
#      381.26,
#      591.86,
#      376.2,
#      612.1,
#      376.2,
#      633.6,
#      377.47,
#      652.57,
#      385.06,
#      670.28,
#      392.65,
#      690.52,
#      397.71,
#      709.49,
#      405.3,
#      728.46,
#      415.41,
#      746.17,
#      429.33,
#      761.35,
#      445.77,
#      775.26,
#      463.48,
#      786.64,
#      482.45,
#      796.76,
#      501.42,
#      801.82,
#      521.66,
#      808.15,
#      541.9,
#      810.68,
#      560.87,
#      811.94,
#      579.84,
#      813.2,
#      598.82,
#      809.41,
#      616.52,
#      796.76,
#      635.5,
#      781.58,
#      649.41,
#      765.14,
#      660.79,
#      748.7,
#      670.91,
#      732.26,
#      677.24,
#      713.28,
#      683.56,
#      693.05,
#      687.35,
#      674.07,
#      691.15,
#      655.1,
#      693.68,
#      634.86,
#      693.68,
#      612.1,
#      693.68,
#      591.86,
#      688.62,
#      570.36,
#      678.5,
#      552.65,
#      665.85,
#      536.21,
#      650.67,
#      522.29,
#      631.7,
#      510.91,
#      613.99,
#      500.79,
#      593.76,
#      493.2,
#      573.52,
#      488.14,
#      554.55,
#      481.82]],
#    'area': 83569.0,
#    'bbox': [376.2, 481.82, 317.48, 331.38],
#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   {'id': 984,
#    'image_id': 484,
#    'category_id': 1,
#    'segmentation': [[1066.94,
#      117.34,
#      1037.55,
#      115.38,
#      1004.25,
#      115.38,
#      972.9,
#      115.38,
#      941.56,
#      115.38,
#      910.21,
#      115.38,
#      876.9,
#      115.38,
#      845.56,
#      123.22,
#      814.21,
#      136.93,
#      784.82,
#      150.64,
#      755.44,
#      162.4,
#      784.82,
#      176.11,
#      816.17,
#      176.11,
#      847.52,
#      178.07,
#      859.27,
#      205.5,
#      857.31,
#      240.77,
#      829.88,
#      256.44,
#      822.05,
#      285.83,
#      822.05,
#      317.17,
#      820.09,
#      346.56,
#      816.17,
#      377.91,
#      810.29,
#      407.29,
#      804.42,
#      436.68,
#      798.54,
#      466.07,
#      790.7,
#      495.46,
#      790.7,
#      526.8,
#      790.7,
#      558.15,
#      784.82,
#      587.54,
#      780.91,
#      620.84,
#      776.99,
#      654.15,
#      771.11,
#      687.45,
#      765.23,
#      716.84,
#      763.27,
#      746.23,
#      757.4,
#      777.57,
#      751.52,
#      808.92,
#      745.64,
#      838.31,
#      739.76,
#      873.57,
#      735.84,
#      902.96,
#      733.89,
#      932.35,
#      729.97,
#      961.74,
#      751.52,
#      989.16,
#      784.82,
#      987.2,
#      816.17,
#      983.29,
#      849.48,
#      983.29,
#      880.82,
#      981.33,
#      910.21,
#      977.41,
#      939.6,
#      975.45,
#      972.9,
#      975.45,
#      1012.09,
#      975.45,
#      1045.39,
#      975.45,
#      1074.78,
#      979.37]],
#    'area': 244792.0,
#    'bbox': [729.97, 115.38, 344.81, 873.78],
#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   {'id': 985,
#    'image_id': 485,
#    'category_id': 1,
#    'segmentation': [[569.58,
#      1547.52,
#      507.54,
#      1544.26,
#      465.09,
#      1573.64,
#      438.97,
#      1622.62,
#      432.44,
#      1674.87,
#      432.44,
#      1727.11,
#      435.7,
#      1776.09,
#      465.09,
#      1818.54,
#      504.27,
#      1851.19,
#      549.99,
#      1874.05,
#      602.23,
#      1877.31,
#      651.21,
#      1874.05,
#      674.07,
#      1828.34,
#      647.94,
#      1779.36,
#      644.68,
#      1730.38,
#      644.68,
#      1678.13,
#      641.41,
#      1622.62,
#      625.09,
#      1573.64]],
#    'area': 62236.0,
#    'bbox': [432.44, 1544.26, 241.63, 333.05],
#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   {'id': 986,
#    'image_id': 485,
#    'category_id': 1,
#    'segmentation': [[1753.23,
#      368.76,
#      1704.26,
#      365.5,
#      1658.54,
#      398.15,
#      1616.09,
#      430.8,
#      1586.71,
#      476.52,
#      1573.64,
#      528.76,
#      1573.64,
#      581.01,
#      1586.71,
#      633.25,
#      1606.3,
#      678.96,
#      1648.75,
#      718.15,
#      1700.99,
#      731.21,
#      1753.23,
#      731.21,
#      1798.95,
#      711.62,
#      1841.4,
#      675.7,
#      1883.84,
#      643.05,
#      1909.97,
#      597.33,
#      1913.23,
#      548.35,
#      1893.64,
#      496.11,
#      1874.05,
#      447.13,
#      1851.19,
#      401.42,
#      1808.74,
#      368.76]],
#    'area': 96008.0,
#    'bbox': [1573.64, 365.5, 339.59, 365.71],
#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   {'id': 987,
#    'image_id': 485,
#    'category_id': 1,
#    'segmentation': [[935.29,
#      120.6,
#      837.33,
#      159.79,
#      794.88,
#      192.44,
#      762.23,
#      238.15,
#      749.17,
#      287.13,
#      778.55,
#      342.64,
#      824.27,
#      319.78,
#      866.72,
#      290.4,
#      915.69,
#      274.07,
#      964.67,
#      264.28,
#      1016.92,
#      261.01,
#      1072.43,
#      264.28,
#      1124.67,
#      277.34,
#      1111.61,
#      228.36,
#      1085.49,
#      185.91,
#      1043.04,
#      153.26]],
#    'area': 44463.0,
#    'bbox': [749.17, 120.6, 375.5, 222.04],
#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   {'id': 988,
#    'image_id': 485,
#    'category_id': 1,
#    'segmentation': [[357.33,
#      316.52,
#      308.36,
#      332.85,
#      265.91,
#      365.5,
#      236.52,
#      407.95,
#      216.93,
#      456.93,
#      210.4,
#      505.9,
#      213.66,
#      558.15,
#      243.05,
#      600.6,
#      285.5,
#      633.25,
#      331.21,
#      652.84,
#      380.19,
#      662.64,
#      432.44,
#      662.64,
#      461.82,
#      620.19,
#      487.95,
#      574.47,
#      520.6,
#      535.29,
#      543.45,
#      486.31,
#      549.99,
#      437.33,
#      523.86,
#      391.62,
#      497.74,
#      345.91,
#      448.76,
#      323.05]],
#    'area': 88641.0,
#    'bbox': [210.4, 316.52, 339.59, 346.12],
#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   {'id': 989,
#    'image_id': 485,
#    'category_id': 1,
#    'segmentation': [

#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   {'id': 994,
#    'image_id': 486,
#    'category_id': 1,
#    'segmentation': [[293.8,
#      409.18,
#      276.53,
#      409.18,
#      260.34,
#      412.42,
#      244.15,
#      418.89,
#      229.04,
#      425.37,
#      211.77,
#      436.16,
#      197.74,
#      446.96,
#      186.95,
#      459.91,
#      175.07,
#      475.02,
#      165.36,
#      491.21,
#      161.04,
#      508.48,
#      157.8,
#      524.67,
#      156.72,
#      540.86,
#      153.49,
#      558.13,
#      153.49,
#      576.47,
#      153.49,
#      593.74,
#      158.88,
#      609.93,
#      164.28,
#      626.12,
#      173.99,
#      643.39,
#      182.63,
#      657.42,
#      198.82,
#      670.38,
#      212.85,
#      679.01,
#      229.04,
#      686.57,
#      248.47,
#      691.96,
#      265.74,
#      694.12,
#      284.08,
#      697.36,
#      302.43,
#      699.52,
#      321.86,
#      699.52,
#      338.05,
#      700.6,
#      353.16,
#      691.96,
#      369.35,
#      685.49,
#      384.46,
#      676.85,
#      399.57,
#      668.22,
#      415.76,
#      657.42,
#      427.64,
#      645.55,
#      434.11,
#      629.36,
#      439.51,
#      613.17,
#      444.9,
#      596.98,
#      448.14,
#      579.71,
#      451.38,
#      562.44,
#      452.46,
#      541.94,
#      451.38,
#      524.67,
#      449.22,
#      507.4,
#      440.59,
#      489.05,
#      429.79,
#      475.02,
#      417.92,
#      462.07,
#      404.97,
#      450.19,
#      389.86,
#      438.32,
#      372.59,
#      429.69,
#      357.48,
#      422.13,
#      339.13,
#      417.81,
#      322.94,
#      414.58]],
#    'area': 69694.0,
#    'bbox': [153.49, 409.18, 298.97, 291.42],
#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   {'id': 995,
#    'image_id': 487,
#    'category_id': 1,
#    'segmentation': [[511.93,
#      512.72,
#      469.92,
#      512.72,
#      433.16,
#      531.1,
#      404.27,
#      562.6,
#      380.64,
#      601.99,
#      370.14,
#      641.38,
#      362.26,
#      680.76,
#      362.26,
#      725.4,
#      372.77,
#      770.04,
#      399.02,
#      806.8,
#      430.53,
#      835.68,
#      467.29,
#      856.68,
#      506.68,
#      867.19,
#      548.69,
#      872.44,
#      585.45,
#      856.68,
#      619.58,
#      833.05,
#      656.34,
#      814.67,
#      666.85,
#      775.29,
#      679.97,
#      735.9,
#      687.85,
#      696.52,
#      690.48,
#      657.13,
#      690.48,
#      615.12,
#      674.72,
#      578.36,
#      648.47,
#      544.22,
#      614.33,
#      523.22,
#      574.95,
#      512.72,
#      535.56,
#      504.84]],
#    'area': 95741.0,
#    'bbox': [362.26, 504.84, 328.22, 367.6],
#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   {'id': 996,
#    'image_id': 488,
#    'category_id': 2,
#    'segmentation': [[175.62,
#      296.24,
#      175.62,
#      415.22,
#      1121.29,
#      411.12,
#      1117.19,
#      294.19]],
#    'area': 111303.0,
#    'bbox': [175.62, 294.19, 945.67, 121.03],
#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   {'id': 997,
#    'image_id': 489,
#    'category_id': 2,
#    'segmentation': [[75.59,
#      244.55,
#      74.33,
#      307.55,
#      585.88,
#      311.33,
#      584.62,
#      250.85]],
#    'area': 31530.0,
#    'bbox': [74.33, 244.55, 511.55, 66.78],
#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   {'id': 998,
#    'image_id': 489,
#    'category_id': 1,
#    'segmentation': [[951.14,
#      234.75,
#      941.42,
#      238.4,
#      938.38,
#      249.33,
#      937.77,
#      259.06,
#      937.77,
#      269.99,
#      937.77,
#      280.93,
#      937.77,
#      290.65,
#      938.99,
#      300.37,
#      939.59,
#      309.49,
#      943.24,
#      318.6,
#      952.35,
#      315.56,
#      955.39,
#      306.45,
#      955.39,
#      294.91,
#      955.39,
#      284.58,
#      955.39,
#      274.85,
#      955.39,
#      264.52,
#      955.39,
#      254.2,
#      955.39,
#      244.47]],
#    'area': 1280.0,
#    'bbox': [937.77, 234.75, 17.62, 83.85],
#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   {'id': 999,
#    'image_id': 490,
#    'category_id': 1,
#    'segmentation': [[994.04,
#      198.48,
#      884.77,
#      288.36,
#      870.67,
#      311.27,
#      865.39,
#      337.71,
#      856.57,
#      365.91,
#      853.05,
#      392.35,
#      842.47,
#      420.54,
#      842.47,
#      450.51,
#      847.76,
#      476.94,
#      851.29,
#      505.14,
#      853.05,
#      533.34,
#      860.1,
#      559.78,
#      879.48,
#      580.93,
#      893.58,
#      605.6,
#      914.73,
#      623.23,
#      942.93,
#      633.8,
#      971.13,
#      639.09,
#      999.33,
#      642.61,
#      1027.53,
#      642.61,
#      1055.73,
#      639.09,
#      1080.4,
#      626.75,
#      1105.08,
#      612.65,
#      1129.75,
#      593.26,
#      1152.66,
#      572.11,
#      1165.0,
#      547.44,
#      1180.86,
#      524.53,
#      1191.44,
#      499.85,
#      1200.25,
#      473.42,
#      1209.06,
#      446.98,
#      1216.11,
#      417.02,
#      1219.64,
#      387.06,
#      1219.64,
#      357.1,
#      1217.87,
#      321.85,
#      1209.06,
#      295.41,
#      1191.44,
#      267.21,
#      1175.57,
#      244.3,
#      1156.19,
#      221.39,
#      1131.51,
#      205.53,
#      1105.08,
#      194.95,
#      1076.88,
#      187.9,
#      1046.92,
#      187.9]],
#    'area': 134146.0,
#    'bbox': [842.47, 187.9, 377.17, 454.71],
#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   {'id': 1000,
#    'image_id': 491,
#    'category_id': 2,
#    'segmentation': [[408.93,
#      463.5,
#      408.93,
#      492.12,
#      605.15,
#      491.1,
#      605.15,
#      461.46]],
#    'area': 5723.0,
#    'bbox': [408.93, 461.46, 196.22, 30.66],
#    'iscrowd': 0,
#    'attributes': {'occluded': False}},
#   ...]}

# %%
# category ID가 반드시 연속이라는 보장이 없음
categories = sorted(coco_data['categories'], key=lambda x: x['id'])

COCO_ID_TO_YOLO_ID = {
    category['id']: yolo_id for yolo_id, category in enumerate(categories)
}

CLASS_NAMES = [category['name'] for category in categories]

print('이미지 수: ', len(coco_data['images']))
print('Annotation 수: ', len(coco_data['annotations']))
print('클래스 : ', CLASS_NAMES)
print('ID 매핑: ', COCO_ID_TO_YOLO_ID)
# Out:
# 이미지 수:  612
# Annotation 수:  1296
# 클래스 :  ['logo', 'text']
# ID 매핑:  {1: 0, 2: 1}

# %% [markdown]
# ### 이미지와 Annotation 확인
# - JSON에 등록된 이미지가 실제 폴더에 모두 존재하는지 확인
# - 클래스별 annotation 수를 확인하면 특정 클래스가 지나치게 적은지도 확인할 수 있음

# %%
image_info_by_id = { image_info['id']: image_info for image_info in coco_data['images']}


missing_images = []

for image_info in coco_data['images']:
    image_path = SOURCE_DIR / image_info['file_name']
    if not image_path.exists():
        missing_images.append(image_info['file_name'])

class_counts = Counter(COCO_ID_TO_YOLO_ID[ann['category_id']] for ann in coco_data['annotations']
                       if ann['category_id'] in COCO_ID_TO_YOLO_ID)

print("누락 이미지 수: ", len(missing_images))
if missing_images:
    print(missing_images)

for class_id, class_name in enumerate(CLASS_NAMES):
    print(f'{class_id}: {class_name} > {class_counts[class_id]} annotations')
# Out:
# 누락 이미지 수:  0
# 0: logo > 933 annotations
# 1: text > 363 annotations

# %% [markdown]
# ### COCO Polygon Annotation 시각화
# - COCO Polygon Annotation의 좌표
# ```
# [x1, y1, x2, y2, x3, y3, ...]
# 최소 3개의 점을 연결하여 객체 외곽을 표현
# ```

# %%
def load_rgb_image(image_path: Path):
    image_bgr = cv2.imread(str(image_path))
    if image_bgr is None:
        raise FileNotFoundError(f'이미지를 읽을 수 없습니다: {image_path}')
    return cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# %%
def visualize_coco_annotation(image_id: int):
    image_info = image_info_by_id.get(image_id)
    if image_info is None:
        raise ValueError(f'존재하지 않는 image_id입니다: {image_id}')

    image = load_rgb_image(SOURCE_DIR / image_info['file_name']).copy()

    for ann in coco_data["annotations"]:
        if ann['image_id'] != image_id:
            continue

        class_id = COCO_ID_TO_YOLO_ID[ann['category_id']]
        class_name = CLASS_NAMES[class_id]

        for polygon in ann.get("segmentation", []):
            if not isinstance(polygon, list) or len(polygon) < 6:
                continue

            points = np.array(polygon, dtype=np.float32).reshape(-1, 2).astype(np.int32)

            cv2.polylines(image, [points], True, (0, 255, 0), 2)

            x, y = points[0]
            cv2.putText(image, class_name, (int(x), max(20, int(y) - 5)),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)

    plt.figure(figsize=(8, 6))
    plt.imshow(image)
    plt.axis('off')
    plt.title(f"COCO Annotation - {image_info['file_name']}")
    plt.show()

# %%
visualize_coco_annotation(387)

# %% [markdown]
# ### COCO > YOLO Segmentation 변환
#
# YOLO Segmentation 라벨
# ```
# class_id x1 y1 x2 y2 x3 y3 ...
# ```
# 좌표는 픽셀 값이 아니라 0 ~ 1 사이로 정규화
#
# - x_norm = x / image_width
# - y_norm = y / image_height

# %%
def coco_polygon_to_yolo_line(class_id, polygon, image_width, image_height):
    if not isinstance(polygon, list) or len(polygon) < 6:
        return None

    if len(polygon) % 2 != 0:
        return None

    normalized_values = []

    for i in range(0, len(polygon), 2):
        x = polygon[i]
        y = polygon[i + 1]
        x_norm = x / image_width
        y_norm = y / image_height

        x_norm = min(max(x_norm, 0.0), 1.0)
        y_norm = min(max(y_norm, 0.0), 1.0)

        normalized_values.extend([x_norm, y_norm])

    coordinates = " ".join(f'{value:.6f}' for value in normalized_values)
    return f'{class_id} {coordinates}'

# %% [markdown]
# ### train / val / test 분할

# %%
SEED = 2026
TRAIN_RATIO = 0.6
VAL_RATIO = 0.2

random.seed(SEED)

all_images = [image_info for image_info in coco_data['images'] 
              if(SOURCE_DIR / image_info['file_name']).exists()]

random.shuffle(all_images)
num_images = len(all_images)
num_train = int(num_images * TRAIN_RATIO)
num_val = int(num_images * VAL_RATIO)

train_images = all_images[:num_train]
val_images = all_images[num_train: num_train + num_val]
test_images = all_images[num_train + num_val:]

print('전체: ', num_images)
print('train: ', len(train_images))
print('val: ', len(val_images))
print('test: ', len(test_images))
# Out:
# 전체:  612
# train:  367
# val:  122
# test:  123

# %% [markdown]
# ### YOLO 폴더 구조 생성
# - YOLO의 명확한 구조는 이미지와 라벨을 분리하는 방식
# - 예) images/train/starbucks11.jpg > labels/train/starbucks11.txt

# %%
def prepare_yolo_split(split_name, split_images):
    image_output_dir = YOLO_ROOT / "images" / split_name
    label_output_dir = YOLO_ROOT / "labels" / split_name

    image_output_dir.mkdir(parents=True, exist_ok=True)
    label_output_dir.mkdir(parents=True, exist_ok=True)

    # 재실행할 때 과거 파일이 남아 섞이는 것을 방지
    for old_file in image_output_dir.iterdir():
        if old_file.is_file():
            old_file.unlink()

    for old_file in label_output_dir.iterdir():
        if old_file.is_file():
            old_file.unlink()

    annotations_by_image = {}

    for ann in coco_data['annotations']:
        annotations_by_image.setdefault(ann['image_id'], []).append(ann)

    for image_info in split_images:
        image_id = image_info['id']
        image_width = image_info['width']
        image_height = image_info['height']
        file_name = image_info['file_name']

        shutil.copy2(SOURCE_DIR / file_name , image_output_dir / file_name)

        yolo_lines = []

        for ann in annotations_by_image.get(image_id, []):
            coco_category_id = ann['category_id']
            if coco_category_id not in COCO_ID_TO_YOLO_ID:
                continue
            class_id = COCO_ID_TO_YOLO_ID[coco_category_id]
            segmentation = ann.get('segmentation', [])

            if not isinstance(segmentation, list):
                continue

            for polygon in segmentation:
                yolo_line = coco_polygon_to_yolo_line(
                    class_id, polygon, image_width, image_height
                )

                if yolo_line is not None:
                    yolo_lines.append(yolo_line)

        label_path = label_output_dir / f'{Path(file_name).stem}.txt'
        if yolo_lines:
            label_path.write_text("\n".join(yolo_lines), encoding='utf-8')

# %%
prepare_yolo_split("train", train_images)
prepare_yolo_split("val", val_images)
prepare_yolo_split("test", test_images)
print("COCO > YOLO Segmentation 변경 완료")
# Out:
# COCO > YOLO Segmentation 변경 완료

# %% [markdown]
# ### YOLO txt 라벨 다시 시각화
# - COCO JSON이 아니라 변환된 YOLO txt를 읽어서 polygon을 그림

# %%
def visualize_yolo_label(split_name, image_name):
    image_path = YOLO_ROOT / "images" / split_name / image_name
    label_path = YOLO_ROOT / "labels" / split_name / f"{Path(image_name).stem}.txt"

    image = load_rgb_image(image_path).copy()
    height, width = image.shape[:2]

    if not label_path.exists():
        raise FileNotFoundError(f'라벨이 없습니다: {label_path}')

    for line in label_path.read_text(encoding="utf-8").splitlines():
        values = line.split()
        class_id = int(values[0])
        points = np.array(list(map(float, values[1:])), dtype=np.float32).reshape(-1, 2)
        points[:, 0] *= width
        points[:, 1] *= height
        points = points.astype(np.int32)

        cv2.polylines(image, [points], True, (0, 255, 0), 2)

        x, y = points[0]
        cv2.putText(image, CLASS_NAMES[class_id], (int(x), max(20, int(y) - 5)),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)

    plt.figure(figsize=(8, 6))
    plt.imshow(image)
    plt.axis('off')
    plt.title(f"COCO Annotation - {image_info['file_name']}")
    plt.show()

# %%
sample_train_image = train_images[0]['file_name']
print("확인 이미지: ", sample_train_image)

visualize_yolo_label("train", sample_train_image)
# Out:
# 확인 이미지:  000064.jpg

# %%
sample_train_image = train_images[81]['file_name']
print("확인 이미지: ", sample_train_image)

visualize_yolo_label("train", sample_train_image)
# Out:
# 확인 이미지:  000428.jpg

# %% [markdown]
# ### YOLO 데이터셋 YAML 생성
# Class ID
# - 0: logo
# - 1: text

# %%
yaml_data = {
    "path": str(YOLO_ROOT.resolve()),
    "train": "images/train",
    "val": "images/val",
    "test": "images/test",
    "names": {
        class_id: class_name for class_id, class_name in enumerate(CLASS_NAMES)
    }
}

YAML_PATH = YOLO_ROOT / "starbucks.yaml"

with YAML_PATH.open("w", encoding="utf-8") as f:
    yaml.safe_dump(yaml_data, f, allow_unicode=True, sort_keys=False)

print(YAML_PATH.read_text(encoding="utf-8"))
# Out:
# path: C:\HyeonKyu\11_CV\data\Starbucks_YOLO
# train: images/train
# val: images/val
# test: images/test
# names:
#   0: logo
#   1: text

# %% [markdown]
# # **3. YOLO11 Segmentation 모델**

# %%
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
elif torch.backends.mps.is_available():
    DEVICE = torch.device('mps')
elif torch.xpu.is_available():
    DEVICE = torch.device('xpu')
else:
    DEVICE = torch.device('cpu')

print(DEVICE)
# Out:
# cpu

# %%
model = YOLO("yolo11s-seg.pt")
print("Model task: ", model.task)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s-seg.pt to 'yolo11s-seg.pt': 100% ━━━━━━━━━━━━ 19.7MB 10.0MB/s 2.0s1.9s<0.1ss
# Model task:  segment

# %%
train_results = model.train(
    data = str(YAML_PATH),
    epochs = 50,
    imgsz = 640,
    batch = 4,
    device = DEVICE,
    workers = 0,
    seed = SEED,
    patience = 20,
    name = "starbucks_yolo11s_seg",
    exist_ok = True
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.146 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.143  Python-3.12.7 torch-2.14.0+cpu CPU (12th Gen Intel Core i7-12700)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\HyeonKyu\11_CV\data\Starbucks_YOLO\starbucks.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=starbucks_yolo11s_seg, nbs=64, nms=None, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\HyeonKyu\11_CV\runs\segment\starbucks_yolo11s_seg, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2026, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1   1474678  ultralytics.nn.modules.head.Segment          [2, 32, 128, 16, None, [128, 256, 512]]
# YOLO11s-seg summary: 203 layers, 10,083,062 parameters, 10,083,046 gradients, 33.2 GFLOPs
#
# Transferred 555/561 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access  (ping: 0.00.0 ms, read: 1532.3481.9 MB/s, size: 219.3 KB)
# train: Scanning C:\HyeonKyu\11_CV\data\Starbucks_YOLO\labels\train... 365 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━
8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.9s/it 30.6s1.7ss
#                    all        122        266       0.81      0.722      0.778      0.566      0.806      0.704      0.757      0.535
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       42/50         0G     0.7189     0.9999     0.5806     0.9756          0         17        640: 100% ━━━━━━━━━━━━ 92/92 2.5s/it 3:522.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.5s/it 23.6s1.5ss
#                    all        122        266      0.775      0.787      0.808       0.58      0.803      0.761      0.804      0.532
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       43/50         0G     0.7275      1.033     0.5816     0.9749          0          4        640: 100% ━━━━━━━━━━━━ 92/92 2.5s/it 3:532.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.6s/it 25.3s1.6ss
#                    all        122        266      0.751      0.752      0.802      0.578      0.872      0.692      0.793      0.542
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       44/50         0G     0.6953     0.9671     0.5639     0.9473          0          5        640: 100% ━━━━━━━━━━━━ 92/92 2.6s/it 3:582.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.5s/it 24.3s1.5ss
#                    all        122        266      0.817       0.72      0.798      0.572       0.83      0.728      0.794      0.533
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       45/50         0G     0.7165      1.036     0.5622      0.964          0          5        640: 100% ━━━━━━━━━━━━ 92/92 2.6s/it 3:562.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.5s/it 24.1s1.5ss
#                    all        122        266      0.847      0.714      0.793      0.574      0.859      0.722      0.792      0.532
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       46/50         0G     0.6832     0.9778     0.5479     0.9559          0          8        640: 100% ━━━━━━━━━━━━ 92/92 2.6s/it 3:562.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.5s/it 24.2s1.5ss
#                    all        122        266       0.78      0.754      0.798      0.581      0.781      0.747      0.786      0.533
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       47/50         0G     0.6918     0.9819      0.557     0.9548          0          4        640: 100% ━━━━━━━━━━━━ 92/92 2.6s/it 3:562.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.5s/it 24.0s1.5ss
#                    all        122        266      0.796      0.762      0.801      0.585      0.823      0.721      0.781      0.541
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       48/50         0G     0.6709     0.9708     0.5404      0.943          0          5        640: 100% ━━━━━━━━━━━━ 92/92 2.6s/it 3:582.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.5s/it 24.2s1.5ss
#                    all        122        266      0.834      0.741      0.806       0.59      0.829      0.721      0.788      0.541
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       49/50         0G     0.6715     0.9872     0.5317     0.9407          0          4        640: 100% ━━━━━━━━━━━━ 92/92 2.6s/it 3:562.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.5s/it 24.2s1.5ss
#                    all        122        266      0.843      0.729       0.81       0.59      0.845      0.721      0.791      0.538
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       50/50         0G     0.6664     0.9569     0.5175     0.9528          0          3        640: 100% ━━━━━━━━━━━━ 92/92 2.7s/it 4:092.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.6s/it 26.3s1.7ss
#                    all        122        266      0.856      0.742      0.809      0.588      0.868      0.723      0.793      0.538
#
# 50 epochs completed in 3.875 hours.
# Optimizer stripped from C:\HyeonKyu\11_CV\runs\segment\starbucks_yolo11s_seg\weights\last.pt, 20.5MB
# Optimizer stripped from C:\HyeonKyu\11_CV\runs\segment\starbucks_yolo11s_seg\weights\best.pt, 20.5MB
#
# Validating C:\HyeonKyu\11_CV\runs\segment\starbucks_yolo11s_seg\weights\best.pt...
# Ultralytics 8.4.143  Python-3.12.7 torch-2.14.0+cpu CPU (12th Gen Intel Core i7-12700)
# YOLO11s-seg summary (fused): 113 layers, 10,067,590 parameters, 0 gradients, 32.9 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.0it/s 15.8s1.0s
#                    all        122        266      0.836       0.74      0.806      0.589      0.829       0.72      0.788      0.541
#                   logo        108        206      0.902      0.848       0.91      0.747      0.901       0.84      0.905      0.721
#                   text         46         60      0.771      0.633      0.702      0.431      0.757        0.6      0.671      0.361
# Speed: 2.0ms preprocess, 109.3ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to C:\HyeonKyu\11_CV\runs\segment\starbucks_yolo11s_seg

# %%
RUN_DIR = PROJECT_ROOT / "runs" / "segment" / "starbucks_yolo11s_seg"
BEST_MODEL_PATH = RUN_DIR / "weights" / "best.pt"
print("best.pt: ", BEST_MODEL_PATH)
# Out:
# best.pt:  c:\HyeonKyu\11_CV\runs\segment\starbucks_yolo11s_seg\weights\best.pt

# %%
# 일반 pretrained 모델이 아니라 Starbucks 데이터로 fine_tuning된 모델을 불러옴
best_model = YOLO(str(BEST_MODEL_PATH))
print("Task :", best_model.task)
print("Classes: ", best_model.names)
# Out:
# Task : segment
# Classes:  {0: 'logo', 1: 'text'}

# %% [markdown]
# ### Validation 성능 평가
#
# Segmentation 모델은 Box와 Mask 성능을 따로 봄
# - metrics.box: Bounding Box 기준
# - metrics.seg: Segmentation Mask 기준

# %%
metrics = best_model.val(
    data=str(YAML_PATH),
    split="val",
    imgsz=640,
    device=DEVICE
)
# Out:
# YOLO11s-seg summary (fused): 113 layers, 10,067,590 parameters, 0 gradients, 32.9 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 2596.4536.1 MB/s, size: 265.3 KB)
# val: Scanning C:\HyeonKyu\11_CV\data\Starbucks_YOLO\labels\val.cache... 121 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 122/122  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.8s/it 14.4s2.1s
#                    all        122        266      0.838      0.739      0.805       0.59      0.834      0.721      0.788      0.541
#                   logo        108        206      0.906      0.844      0.907      0.746      0.906      0.843      0.904      0.721
#                   text         46         60      0.771      0.633      0.702      0.434      0.762        0.6      0.671      0.361
# Speed: 2.0ms preprocess, 96.0ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\HyeonKyu\11_CV\runs\segment\val

# %%
print("BOX mAP50: ", metrics.box.map50)
print("BOX mAP50-95: ", metrics.box.map)
print("Mask mAP50: ", metrics.seg.map50)
print("Mask mAP50-95: ", metrics.seg.map)
# Out:
# BOX mAP50:  0.8045767261893214
# BOX mAP50-95:  0.5901318119192724
# Mask mAP50:  0.7875432880123026
# Mask mAP50-95:  0.5412555224336678

# %% [markdown]
# ### Segmentation 추론
# - result.boxes.xyxy: Bounding Box 좌표
# - result.boxes.cls: class ID
# - result.boxes.conf: confidence score
# - result.masks.xy: polygon 좌표
# - result.masks.data: mask tensor

# %%
TEST_IMAGE_DIR = YOLO_ROOT / "images" / "test"

predict_results = best_model.predict(
    source=str(TEST_IMAGE_DIR),
    imgsz=640,
    conf=0.30,
    device=DEVICE,
    retina_masks=True,
    save=True,
    name="starbucks_yolo11s_set_predict",
    exist_ok=True
)
# Out:
# image 1/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000003.jpg: 480x640 1 logo, 98.4ms
# image 2/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000010.jpg: 640x416 1 logo, 84.8ms
# image 3/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000012.jpg: 480x640 1 logo, 74.2ms
# image 4/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000026.jpg: 288x640 4 logos, 1 text, 78.1ms
# image 5/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000033.jpg: 480x640 1 logo, 1 text, 91.4ms
# image 6/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000034.jpg: 480x640 1 logo, 1 text, 78.0ms
# image 7/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000035.jpg: 480x640 1 logo, 73.2ms
# image 8/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\
123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000619.jpg: 640x416 1 logo, 1 text, 99.2ms
# image 104/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000622.jpg: 512x640 1 logo, 1 text, 82.9ms
# image 105/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000624.jpg: 640x480 1 logo, 74.4ms
# image 106/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000632.jpg: 640x480 1 logo, 64.4ms
# image 107/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000633.jpg: 384x640 2 logos, 69.6ms
# image 108/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000634.jpg: 640x512 2 logos, 92.9ms
# image 109/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000635.jpg: 640x480 1 logo, 63.3ms
# image 110/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000638.jpg: 640x640 1 logo, 89.0ms
# image 111/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000641.jpg: 576x640 2 logos, 109.4ms
# image 112/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000646.jpg: 640x480 1 logo, 75.8ms
# image 113/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000650.jpg: 384x640 1 logo, 48.8ms
# image 114/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000654.jpg: 384x640 3 texts, 62.5ms
# image 115/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000657.jpg: 640x640 2 logos, 117.1ms
# image 116/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000658.jpg: 640x480 2 logos, 72.1ms
# image 117/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000662.jpg: 480x640 (no detections), 64.5ms
# image 118/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000664.jpg: 640x640 2 logos, 72.5ms
# image 119/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000665.jpg: 640x640 2 logos, 3 texts, 83.1ms
# image 120/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000667.jpg: 480x640 1 logo, 1 text, 58.1ms
# image 121/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000668.jpg: 640x640 1 logo, 79.7ms
# image 122/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000669.jpg: 448x640 1 logo, 71.6ms
# image 123/123 c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000671.jpg: 640x640 2 logos, 84.3ms
# Speed: 2.1ms preprocess, 80.7ms inference, 13.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\HyeonKyu\11_CV\runs\segment\starbucks_yolo11s_set_predict

# %%
for result in predict_results[:3]:
    print("=" * 70)
    print("image:", result.path)

    if result.boxes is not None:
        print("classes    :", result.boxes.cls.cpu().tolist())
        print("confidence :", result.boxes.conf.cpu().tolist())
        print("boxes xyxy :")
        print(result.boxes.xyxy.cpu().numpy())

    if result.masks is not None:
        print("mask tensor shape:", tuple(result.masks.data.shape))
        print("polygon 개수     :", len(result.masks.xy))
    else:
        print("검출된 segmentation mask가 없습니다.")
# Out:
# ======================================================================
# image: c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000003.jpg
# classes    : [0.0]
# confidence : [0.8687225580215454]
# boxes xyxy :
# [[     1459.3      808.96      1599.7      1042.2]]
# mask tensor shape: (1, 1155, 1600)
# polygon 개수     : 1
# ======================================================================
# image: c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000010.jpg
# classes    : [0.0]
# confidence : [0.9057901501655579]
# boxes xyxy :
# [[     441.62      751.37      630.49      982.15]]
# mask tensor shape: (1, 1500, 922)
# polygon 개수     : 1
# ======================================================================
# image: c:\HyeonKyu\11_CV\data\Starbucks_YOLO\images\test\000012.jpg
# classes    : [0.0]
# confidence : [0.9340009093284607]
# boxes xyxy :
# [[     345.81      38.073         868      516.89]]
# mask tensor shape: (1, 956, 1300)
# polygon 개수     : 1

# %%
if not predict_results:
    raise RuntimeError("추론 결과가 없습니다.")

result = predict_results[0]

plotted_bgr = result.plot()
plotted_rgb = cv2.cvtColor(
    plotted_bgr,
    cv2.COLOR_BGR2RGB
)

plt.figure(figsize=(10, 8))
plt.imshow(plotted_rgb)
plt.axis("off")
plt.title("YOLO11 Starbucks Instance Segmentation")
plt.show()
